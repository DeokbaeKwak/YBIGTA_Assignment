# %% [markdown]
# # REST API 실습
#
# 22th DE 김원

# %% [markdown]
# ## Python에서

# %%
import requests
# GET 요청 보내기
response = requests.get('https://reqres.in/api/users?page=2')

# 응답 확인
if response.status_code == 200:
    res = response.json()
    print(res)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)

# %%
res

# %%
res['data'][0]

# %%
import pandas as pd
df = pd.DataFrame(res['data'])
df

# %% [markdown]
# ## terminal에서

# %% [markdown]
# 가장 간단한 요청입니다 curl + 요청을 보낼 주소 위는 코랩이기 때문에 터미널명령어를 !앞에 붙여 실행합니다 터미널에서는 !안붙여도 괜찮아요!!

# %%
# !curl https://reqres.in/api/users?page=2

# %% [markdown]
# Curl에 여러가지 옵션을 추가할 수 있습니다
#
# -X : HTTP 메서드 지정
# <br>
#
# GET: 리소스를 가져오기 위한 요청입니다. 기본적으로 curl이 사용하는 메서드입니다.<br>
# POST: 리소스를 생성하기 위한 요청입니다. 데이터를 서버로 전송할 때 사용됩니다.<br>
# PUT: 리소스를 수정하기 위한 요청입니다. 전체 리소스를 업데이트합니다.<br>
# PATCH: 리소스를 일부 수정하기 위한 요청입니다. 부분적인 업데이트를 수행할 때 사용됩니다.<br>
# DELETE: 리소스를 삭제하기 위한 요청입니다.
#
# <br>
#
# -H : header 설정 header란 무엇일까? - 범위를 벗어나므로 신원을 확인하거나, 추가적인 정보가 담겨있는 부분: <br> => 메타데이터가 담겨있는 부분입니다!  <br>
#
# -d : data의 약자로 데이터를 넘겨줍니다
#
#
# <br>
#
# 아래의 예시의 경우, 게시판 홈페이지에 사람을 추가하는 예시! <br>
#
# 리소스를 생성하기 때문에 POST method로, 추가해야할 데이터를 -d 인자로 넘겨줍니다

# %%
# !curl -X POST -H "Content-Type: application/json" -d '{"name": "John", "age":30}' https://reqres.in/api/users

# %% [markdown]
# 위 코드를 실행하면, 정상응답이 나오는 경우 reqres.in 페이지에 /api/users에 새로운 유저를 등록 요청하는 request입니다!

# %% [markdown]
# ### 위를 파이썬 버전으로

# %%
import requests
import json

url = 'https://reqres.in/api/users'
headers = {'Content-Type': 'application/json'}
data = {'name': 'John', 'age': 30}


# post method로 요청

response = requests.post(url, headers=headers, data=json.dumps(data))

if response.status_code == 201: # 상태코드가 201이라면(201 : 요청 정상처리 상태코드 )
    result = response.json()
    print('사용자 생성 완료:', result)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)

# %%
res['data'][0]

# %% [markdown]
# # 페이지를 순회하며 데이터 프레임 만들기! + 약간의 전처리

# %%
import requests
# GET 요청 보내기
response = requests.get('https://reqres.in/api/users?page=2')

# 응답 확인
if response.status_code == 200:
    res = response.json()
    print(res)
else:
    print('요청에 실패했습니다. 상태 코드:', res.status_code)

# %% [markdown]
# # 원래 여러분들이 사용하실 때는...
#
# 보통 API의 호출양이 지정되어 있어서, API 세션 아이디, 키가 보통 필요해요!
#
# </br>
#
# 밑에 하고자 했던 코드는 여러페이지에 걸쳐 순회해서 데이터프레임으로 만드는 과정을 보여드리려고했는데,
# 저게 api가 연습용 서버여서 조금 호출 횟수에 제한된 것 같네요!! 원래 1페이지 부터 11페이지까지 6 x 11 행이 나와야하는데, 무료이다보니 서버에 부담이 되어 time.sleep(5)로 해봤는데도 안되네요! 하여튼 예시로 참고하면 좋을 것 같습니다!

# %%
import requests
import pandas as pd
import time

# 빈 데이터프레임 생성
df_combined = pd.DataFrame()

# 페이지 순회
for page in range(1, 11):
    # GET 요청 보내기
    url = f'https://reqres.in/api/users?page={page}'
    response = requests.get(url)

    # 응답 확인
    if response.status_code == 200:
        data = response.json()
        users = data['data']

        # 데이터프레임으로 변환
        df = pd.DataFrame(users)

        # 데이터프레임 결합
        df_combined = pd.concat([df_combined, df], ignore_index=True)
    else:
        print(f'페이지 {page} 요청에 실패했습니다. 상태 코드:', response.status_code)

# 합쳐진 데이터프레임 출력 (아쉽게도 안됨)
df_combined

# %% [markdown]
# # 과제 !! 나쁜 사람 아닙니다
#
#
# **개념 요약!! 아래 마크다운을 채워주세요 !! **
#
# 챗지피티 사용금지

# %% [markdown]
# ## API란 -> Application Programming Interface의 줄임말로 서로 다른 프로그램끼리 데이터를 주고 받을 수 있도록 하는 하나의 코드, 혹은 인터페이스를 의미한다.
#
# ## REST API란 -> 웹 데이터, 자원에 접근할 때 사용할 수 있는 API 중 하나로 특정 자원을 업로드, 읽어오기, 업데이트하기, 삭제하기 등의 기능을 수행할 수 있다.
#
# ## 각각에 대응하는 HTTP의 메서드를 적어주세요
#
# ### Create -> POST
# ### Read -> GET
# ### Update -> PUT / PATCH
# ### Delete -> DELETE

# %% [markdown]
# ## 실습 과제 1 공식문서를 읽고 아래의 예시코드에 파라미터를 바꿔서 보낸 결과 확인하기!!
#
# 공식문서에 파라미터들을 직접 넘겨줘서 요청을 보내면 됩니다!

# %% [markdown]
# <https://punkapi.com/documentation/v2>

# %%
# !curl https://api.punkapi.com/v2/beers
# Out:
# [{"id":1,"name":"Buzz","tagline":"A Real Bitter Experience.","first_brewed":"09/2007","description":"A light, crisp and bitter IPA brewed with English and American hops. A small batch brewed only once.","image_url":"https://images.punkapi.com/v2/keg.png","abv":4.5,"ibu":60,"target_fg":1010,"target_og":1044,"ebc":20,"srm":10,"ph":4.4,"attenuation_level":75,"volume":{"value":20,"unit":"litres"},"boil_volume":{"value":25,"unit":"litres"},"method":{"mash_temp":[{"temp":{"value":64,"unit":"celsius"},"duration":75}],"fermentation":{"temp":{"value":19,"unit":"celsius"}},"twist":null},"ingredients":{"malt":[{"name":"Maris Otter Extra Pale","amount":{"value":3.3,"unit":"kilograms"}},{"name":"Caramalt","amount":{"value":0.2,"unit":"kilograms"}},{"name":"Munich","amount":{"value":0.4,"unit":"kilograms"}}],"hops":[{"name":"Fuggles","amount":{"value":25,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"First Gold","amount":{"value":25,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Fuggles","amount":{"value":37.5,"unit":"grams"},"add":"middle","attribute":"flavour"},{"name":"First Gold","amount":{"value":37.5,"unit":"grams"},"add":"middle","attribute":"flavour"},{"name":"Cascade","amount":{"value":37.5,"unit":"grams"},"add":"end","attribute":"flavour"}],"yeast":"Wyeast 1056 - American Ale™"},"food_pairing":["Spicy chicken tikka masala","Grilled chicken quesadilla","Caramel toffee cake"],"brewers_tips":"The earthy and floral aromas from the hops can be overpowering. Drop a little Cascade in at the end of the boil to lift the profile with a bit of citrus.","contributed_by":"Sam Mason <samjbmason>"},{"id":2,"name":"Trashy Blonde","tagline":"You Know You Shouldn't","first_brewed":"04/2008","description":"A titillating, neurotic, peroxide punk of a Pale Ale. Combining attitude, style, substance, and a little bit of low self esteem for good measure; what would your mother say? The seductive lure of the sassy passion fruit hop proves too much to resist. All that is even before we get onto the fact that there are no additives, preservatives, pasteurization or strings attached. All wrapped up with the customary BrewDog bite and imaginative twist.","image_url":"https://images.punkapi.com/v2/2.png","abv":4.1,"ibu":41.5,"target_fg":1010,"target_og":1041.7,"ebc":15,"srm":15,"ph":4.4,"attenuation_level":76,"volume":{"value":20,"unit":"litres"},"boil_volume":{"value":25,"unit":"litres"},"method":{"mash_temp":[{"temp":{"value":69,"unit":"celsius"},"duration":null}],"fermentation":{"temp":{"value":18,"unit":"celsius"}},"twist":null},"ingredients":{"malt":[{"name":"Maris Otter Extra Pale","amount":{"value":3.25,"unit":"kilograms"}},{"name":"Caramalt","amount":{"value":0.2,"unit":"kilograms"}},{"name":"Munich","amount":{"value":0.4,"unit":"kilograms"}}],"hops":[{"name":"Amarillo","amount":{"value":13.8,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Simcoe","amount":{"value":13.8,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Amarillo","amount":{"value":26.3,"unit":"grams"},"add":"end","attribute":"flavour"},{"name":"Motueka","amount":{"value":18.8,"unit":"grams"},"add":"end","attribute":"flavour"}],"yeast":"Wyeast 1056 - American Ale™"},"food_pairing":["Fresh crab with lemon","Garlic butter dipping sauce","Goats cheese salad","Creamy lemon bar doused in powdered sugar"],"brewers_tips":"Be careful not to collect too much wort from the mash. Once the sugars are all washed out there are some very unpleasant grainy tasting compounds that can be extracted into the wort.","contributed_by":"Sam Mason <samjbmason>"},{"id":3,"name":"Berliner Weisse With Yuzu - B-Sides","tagline":"Japanese Citrus Berliner Weisse.","first_brewed":"11/2015","description":"Japanese citrus fruit intensifies the sour nature of this German classic.","image_url":"https://images.punkapi.com/v2/keg.png","abv":4.2,"ibu":8,"target_fg":1007,"target_og":1040,"ebc":8,"srm":4,"ph":3.2,"attenuation_level":83,"volume":{"value":20,"unit":"litres"},"bo ...

# %% [markdown]
# ```
# response = requests.get('https://reqres.in/api/users?page=2&per_page=10')
# response.get(url,params= {'page': 2, 'per_page':10 })
# ```
#
#
#
# 위에 두개는 같은 요청입니다! 뒤에 파라미터들이 ?으로 , 파라미터가 여러개일 경우 &으로 연결됩니다!

# %%
import requests
import json
import time

url = 'https://api.punkapi.com/v2/beers'
headers = {'Content-Type': 'application/json'}
# 파라미터로 인자 넘겨줄 수 있음!!
# 아래 params 코드에 인자들을 공식문서를 확인하여 추가하시거나 바꿔주세요!!
# 도수는 6도 초과, 생산일자는 2019년 3월 이전인 맥주들을 15개씩 나눴을 경우의 1페이지 데이터를 가져옴
params= {'page': 1, 'per_page':15, 'abv_gt':6,'brewed_before':'03-2019'}

response = requests.get(url, headers=headers,params=params)

if response.status_code == 200:
    result = response.json()
    print('받아온 데이터:', result)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)
# Out:
# 받아온 데이터: [{'id': 4, 'name': 'Pilsen Lager', 'tagline': 'Unleash the Yeast Series.', 'first_brewed': '09/2013', 'description': 'Our Unleash the Yeast series was an epic experiment into the differences in aroma and flavour provided by switching up your yeast. We brewed up a wort with a light caramel note and some toasty biscuit flavour, and hopped it with Amarillo and Centennial for a citrusy bitterness. Everything else is down to the yeast. Pilsner yeast ferments with no fruity esters or spicy phenols, although it can add a hint of butterscotch.', 'image_url': 'https://images.punkapi.com/v2/4.png', 'abv': 6.3, 'ibu': 55, 'target_fg': 1012, 'target_og': 1060, 'ebc': 30, 'srm': 15, 'ph': 4.4, 'attenuation_level': 80, 'volume': {'value': 20, 'unit': 'litres'}, 'boil_volume': {'value': 25, 'unit': 'litres'}, 'method': {'mash_temp': [{'temp': {'value': 65, 'unit': 'celsius'}, 'duration': None}], 'fermentation': {'temp': {'value': 9, 'unit': 'celsius'}}, 'twist': None}, 'ingredients': {'malt': [{'name': 'Extra Pale', 'amount': {'value': 4.58, 'unit': 'kilograms'}}, {'name': 'Caramalt', 'amount': {'value': 0.25, 'unit': 'kilograms'}}, {'name': 'Dark Crystal', 'amount': {'value': 0.06, 'unit': 'kilograms'}}, {'name': 'Munich', 'amount': {'value': 0.25, 'unit': 'kilograms'}}], 'hops': [{'name': 'Centennial', 'amount': {'value': 5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Amarillo', 'amount': {'value': 5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Centennial', 'amount': {'value': 10, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Amarillo', 'amount': {'value': 10, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Centennial', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}, {'name': 'Amarillo', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}], 'yeast': 'Wyeast 2007 - Pilsen Lager™'}, 'food_pairing': ['Spicy crab cakes', 'Spicy cucumber and carrot Thai salad', 'Sweet filled dumplings'], 'brewers_tips': 'Play around with the fermentation temperature to get the best flavour profile from the individual yeasts.', 'contributed_by': 'Ali Skinner <AliSkinner>'}, {'id': 5, 'name': 'Avery Brown Dredge', 'tagline': "Bloggers' Imperial Pilsner.", 'first_brewed': '02/2011', 'description': 'An Imperial Pilsner in collaboration with beer writers. Tradition. Homage. Revolution. We wanted to showcase the awesome backbone of the Czech brewing tradition, the noble Saaz hop, and also tip our hats to the modern beers that rock our world, and the people who make them.', 'image_url': 'https://images.punkapi.com/v2/5.png', 'abv': 7.2, 'ibu': 59, 'target_fg': 1027, 'target_og': 1069, 'ebc': 10, 'srm': 5, 'ph': 4.4, 'attenuation_level': 67, 'volume': {'value': 20, 'unit': 'litres'}, 'boil_volume': {'value': 25, 'unit': 'litres'}, 'method': {'mash_temp': [{'temp': {'value': 66, 'unit': 'celsius'}, 'duration': 70}], 'fermentation': {'temp': {'value': 10, 'unit': 'celsius'}}, 'twist': None}, 'ingredients': {'malt': [{'name': 'Lager Malt', 'amount': {'value': 6.63, 'unit': 'kilograms'}}, {'name': 'Wheat', 'amount': {'value': 0.38, 'unit': 'kilograms'}}], 'hops': [{'name': 'Saaz', 'amount': {'value': 60, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Saaz', 'amount': {'value': 60, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Saaz', 'amount': {'value': 60, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}], 'yeast': 'Wyeast 2007 - Pilsen Lager™'}, 'food_pairing': ['Vietnamese squid salad', 'Chargrilled corn on the cob with paprika butter', 'Strawberry and rhubarb pie'], 'brewers_tips': 'Make sure you have a big enough yeast starter to ferment through the OG and lager successfully.', 'contributed_by': 'Sam Mason <samjbmason>'}, {'id': 7, 'name': 'AB:12', 'tagline': 'Imperial Black Belgian Ale.', 'first_brewed': '07/2012', 'description': 'An Imperial Black Bel ...

# %%
import pandas as pd

df = pd.DataFrame(result)
df
# Out:
#     id                          name  \
# 0    4                  Pilsen Lager
# 1    5            Avery Brown Dredge
# 2    7                         AB:12
# 3    9                         AB:07
# 4   10                    Bramling X
# 5   11                Misspent Youth
# 6   15                     Mixtape 8
# 7   16              Libertine Porter
# 8   17                         AB:06
# 9   19  Hello My Name Is Mette-Marit
# 10  20                      Rabiator
# 11  22   Devine Rebel (w/ Mikkeller)
# 12  23                         Storm
# 13  24            The End Of History
# 14  27                         Dog B
#
#                                               tagline first_brewed  \
# 0                           Unleash the Yeast Series.      09/2013
# 1                         Bloggers' Imperial Pilsner.      02/2011
# 2                         Imperial Black Belgian Ale.      07/2012
# 3                        Whisky Cask-Aged Scotch Ale.      03/2010
# 4                       Single Hop IPA Series - 2011.      01/2011
# 5                            Milk & Honey Scotch Ale.      04/2013
# 6   An Epic Fusion Of Old Belgian, American New Wa...      01/2012
# 7                       Dry-Hopped Aggressive Porter.      01/2012
# 8                                 Imperial Black IPA.      04/2011
# 9                             Lingonberry Double IPA.      06/2013
# 10                                Imperial Wheat Beer      03/2011
# 11                              Oak-aged Barley Wine.      12/2008
# 12                             Islay Whisky Aged IPA.      12/2007
# 13                        The World's Strongest Beer.      06/2011
# 14             Cacao, Coffee Chili Anniversary Stout.      05/2013
#
#                                           description  \
# 0   Our Unleash the Yeast series was an epic exper...
# 1   An Imperial Pilsner in collaboration with beer...
# 2   An Imperial Black Belgian Ale aged in old Inve...
# 3   Whisky cask-aged imperial scotch ale. Beer per...
# 4   Good old Bramling Cross is elegant, refined, a...
# 5   The brainchild of our small batch brewer, Geor...
# 6   This recipe is for the Belgian Tripel base. A ...
# 7   An avalanche of cross-continental hop varietie...
# 8   Our sixth Abstrakt, this imperial black IPA co...
# 9   We sent this beer to Norway where it was known...
# 10  Imperial Wheat beer / Weizenbock brewed by a h...
# 11  Two of Europe's most experimental, boundary-pu...
# 12  Dark and powerful Islay magic infuses this tro...
# 13  The End of History: The name derives from the ...
# 14  Our anniversary stout was based on AB:04, one ...
#
#                                 image_url    abv    ibu  target_fg  target_og  \
# 0     https://images.punkapi.com/v2/4.png   6.30   55.0       1012       1060
# 1     https://images.punkapi.com/v2/5.png   7.20   59.0       1027       1069
# 2     https://images.punkapi.com/v2/7.png  11.20   35.0       1017       1108
# 3     https://images.punkapi.com/v2/9.png  12.50   30.0       1020       1106
# 4    https://images.punkapi.com/v2/10.png   7.50   75.0       1013       1068
# 5   https://images.punkapi.com/v2/keg.png   7.30   30.0       1020       1079
# 6    https://images.punkapi.com/v2/15.png  14.50   50.0       1014       1093
# 7    https://images.punkapi.com/v2/16.png   6.10   45.0       1020       1067
# 8    https://images.punkapi.com/v2/17.png  11.20  150.0       1013       1098
# 9    https://images.punkapi.com/v2/19.png   8.20   70.0       1013       1076
# 10  https://images.punkapi.com/v2/keg.png  10.27   26.0       1014       1092
# 11   https://images.punkapi.com/v2/22.png  12.50  100.0       1030       1093
# 12   https://images.punkapi.com/v2/23.png   8.00   60.0       1010       1082
# 13   https://images.punkapi.com/v2/24.png  55.00    NaN       1000       1112
# 14   https://images.punkapi.com/v2/27.png  15.00   90.0       1003       1120
#
#     ...    srm   ph  attenuation_level                           volume  \
# 0   ...   15.0  4.4               80.0  {'value': 20, 'unit': 'litres'}
# 1   ...    5.0  4.4               67.0  {'value': 20, 'unit': 'litres'}
# 2   ...   40.0  5.3               84.0  {'value': 20, 'unit': 'litres'}
# 3   ...   42.0  5.6               83.0  {'value': 20, 'unit': 'litres'}
# 4   ...   11.0  4.4               80.9  {'value': 20, 'unit': 'litres'}
# 5   ...   60.0  4.4               74.7  {'value': 20, 'unit': 'litres'}
# 6   ...   20.0  4.4               85.0  {'value': 20, 'unit': 'litres'}
# 7   ...  109.5  4.4               70.1  {'value': 20, 'unit': 'litres'}
# 8   ...   35.0  NaN               87.0  {'value': 20, 'unit': 'litres'}
# 9   ...    NaN  4.4               83.0  {'value': 20, 'unit': 'litres'}
# 10  ...   12.0  4.4               85.0  {'value': 20, 'unit': 'litres'}
# 11  ...   18.0  4.4               68.0  {'value': 20, 'unit': 'litres'}
# 12  ...    6.0  4.4               86.0  {'value': 20, 'unit': 'litres'}
# 13  ...    NaN  4.4              100.0  {'value': 20, 'unit': 'litres'}
# 14  ...   50.0  4.4               98.0  {'value': 20, 'unit': 'litres'}
#
#                         boil_volume  \
# 0   {'value': 25, 'unit': 'litres'}
# 1   {'value': 25, 'unit': 'litres'}
# 2   {'value': 25, 'unit': 'litres'}
# 3   {'value': 25, 'unit': 'litres'}
# 4   {'value': 25, 'unit': 'litres'}
# 5   {'value': 25, 'unit': 'litres'}
# 6   {'value': 25, 'unit': 'litres'}
# 7   {'value': 25, 'unit': 'litres'}
# 8   {'value': 25, 'unit': 'litres'}
# 9   {'value': 25, 'unit': 'litres'}
# 10  {'value': 25, 'unit': 'litres'}
# 11  {'value': 25, 'unit': 'litres'}
# 12  {'value': 25, 'unit': 'litres'}
# 13  {'value': 25, 'unit': 'litres'}
# 14  {'value': 25, 'unit': 'litres'}
#
#                                                method  \
# 0   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 1   {'mash_temp': [{'temp': {'value': 66, 'unit': ...
# 2   {'mash_temp': [{'temp': {'value': 69, 'unit': ...
# 3   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 4   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 5   {'mash_temp': [{'temp': {'value': 67, 'unit': ...
# 6   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 7   {'mash_temp': [{'temp': {'value': 68, 'unit': ...
# 8   {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 9   {'mash_temp': [{'temp': {'value': 66, 'unit': ...
# 10  {'mash_temp': [{'temp': {'value': 64, 'unit': ...
# 11  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 12  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 13  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 14  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
#
#                                           ingredients  \
# 0   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 1   {'malt': [{'name': 'Lager Malt', 'amount': {'v...
# 2   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 3   {'malt': [{'name': 'Munich', 'amount': {'value...
# 4   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 5   {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 6   {'malt': [{'name': 'Pale Ale - Tipple', 'amoun...
# 7   {'malt': [{'name': 'Extra Pale - Spring Blend'...
# 8   {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 9   {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 10  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 11  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 12  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 13  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 14  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
#
#                                          food_pairing  \
# 0   [Spicy crab cakes, Spicy cucumber and carrot T...
# 1   [Vietnamese squid salad, Chargrilled corn on t...
# 2   [Tandoori lamb with pomegranate, Beef Wellingt...
# 3   [Kedgeree, Scotch broth with sourdough bread, ...
# 4   [Warm blackberry pie, Vinegar doused fish and ...
# 5   [Roasted garlic and chilli infused camembert c...
# 6   [Coriander & chilli crab cakes, Goats cheese s...
# 7   [Blue cheese beef burger, Glazed short ribs, C...
# 8   [Coffee dusted venison loin, Memphis-style bee...
# 9   [Fårikål (mutton stew) with a spicy twist, F...
# 10  [Grilled portabello mushroom burger, Chicken s...
# 11  [Stilton on gingerbread biscuits, Pot roasted ...
# 12          [Oysters, Hickory smoked ham, Rocky Road]
# 13  [Roasted wood pigeon with black pudding, Pan s...
# 14  [Blackened cajun beef, Blue cheese, Flourless ...
#
#                                          brewers_tips  \
# 0   Play around with the fermentation temperature ...
# 1   Make sure you have a big enough yeast starter ...
# 2   Don't worry too much about controlling the tem...
# 3   Authentic heather honey adds a beautiful flora...
# 4   Getting good Bramling Cross is key. Most Engli...
# 5   Lots of malt in this one. Mash-in in stages, a...
# 6   Brew twice as much Belgian Tripel as you were ...
# 7   Mash in at a higher temperature to leave more ...
# 8          Boil down to desired OG (about 17 litres).
# 9   Using crushed cranberries will dry out the bee...
# 10  If you are struggling to get that authentic he...
# 11  Rack off to a secondary fermenter before pitch...
# 12  After primary fermentation is complete, rack o...
# 13  You'll have to get this one all the way down t...
# 14  Be really careful when mashing, as this amount...
#
#               contributed_by
# 0   Ali Skinner <AliSkinner>
# 1     Sam Mason <samjbmason>
# 2     Sam Mason <samjbmason>
# 3     Sam Mason <samjbmason>
# 4     Sam Mason <samjbmason>
# 5     Sam Mason <samjbmason>
# 6     Sam Mason <samjbmason>
# 7     Sam Mason <samjbmason>
# 8     Sam Mason <samjbmason>
# 9     Sam Mason <samjbmason>
# 10    Sam Mason <samjbmason>
# 11    Sam Mason <samjbmason>
# 12    Sam Mason <samjbmason>
# 13    Sam Mason <samjbmason>
# 14    Sam Mason <samjbmason>
#
# [15 rows x 21 columns]

# %% [markdown]
# ## 과제 2 컨퍼런스 혹은 신입기수 세션에서 데이터를 끌어올 수 있는 API를 찾아보시고 찾기!
#
#
#
# - response 응답의 구조를 파악하여 어떤 열을 어떻게 활용할 수 있을지 적어보세요!
#
# - 찾은 API 명세서 -> 활용방안을 적어주시면 됩니다!

# %% [markdown]
# 추천 :
#
# 요즘은 다른 거를 가져다가 쓰는 게 또 능력이죠
#
# ### <https://www.reddit.com/dev/api/>
#
# ### <https://developers.kakao.com/>
#
# ### <https://developers.naver.com/main/>
#
# ### <https://platform.openai.com/docs/introduction>

# %% [markdown]
# # 아래 작성해주시면 됩니다!!

# %% [markdown]
# ### 사용할 API : 네이버 지역 검색 API, OpenAI ChatGPT API
#
# ### 사용할 기능 또는 api 응답에서 제공되는 변수 : 네이버 지역 검색 API에서 rss/channel/item/category 메서드를 이용해 식당 및 해당 식당에서 취급하는 음식의 정보를 가져오고 해당 식당의 이름, 도로명주소를 각각 rss/channel/item/title, rss/channel/item/roadAddress 메서드를 통해 가져올 것이다. ChatGPT API를 통해서는 위에서 가져온 음식을 기반으로 음식과 관련된 키워드를 생성하고, 이용자가 질의를 통해 전달한 내용과 가장 비슷한 음식을 찾도록 할 것이다.
#
# ### 활용 방안 : 이용자에게 서비스를 제공하기 이전에, 네이버 지역 검색 API를 이용하여 이용자의 현재 위치를 기반으로 근처의 음식점들과 해당 음식점들이 취급하는 음식들의 정보를 가져올 것이다. 그리고 각 음식점에서 판매하는 음식들의 키워드를 ChatGPT를 통해 생성하여 데이터베이스를 만들어둘 것이다. 실제 서비스에서는 여러 개의 질의를 통해 이용자가 먹고 싶어하는 음식의 특징을 추릴 것이다. 이용자의 답변과 일치하는 키워드를 ChatGPT API를 통해 생성할 것이며 질의가 끝난 뒤에는 생성된 키워드를 바탕으로 키워드가 일치하는, 즉 이용자가 좋아할만한 식당들을 추천할 것이다.

# %% [markdown]
# # 출처
#
# - 내머리
# - 챗지피티
